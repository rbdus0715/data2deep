# %% [markdown]
# <a href="https://colab.research.google.com/github/rbdus0715/Machine-Learning/blob/main/study/cuda/01.intro-cuda/08.memory_transfer_between_host_device.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvcc --version
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# %load_ext nvcc_plugin

# %% [markdown]
# ### **Host <-> Device**
#
# - 128개의 스레드
# - 2개의 스레드 블럭, 하나당 64개
#
# |C|CUDA|
# |-|-|
# |malloc|cudaMalloc|
# |memset|cudaMemset|
# |free|cudaFree|

# %%
# %%cu
# #include "cuda_runtime.h"
# #include "device_launch_parameters.h"
# #include <stdio.h>
# #include <stdlib.h>
# #include <cstring>
# #include <time.h>
#
# __global__ void mem_trs_test(int * input) {
#     // 그리드 블럭과 스레드 블럭이 1차원이므로 gid는 다음과 같다.
#     int gid = blockIdx.x * blockDim.x + threadIdx.x;
#     printf("tid : %d, gid : %d, value : %d \n", threadIdx.x, gid, input[gid]);
# }
#
# int main() {
#
#     int size = 128;
#     int byte_size = size * sizeof(int);
#
#     int * h_input;
#     // 말록 함수는 void 포인터를 반환하므로 원하는 타입의 포인터로 캐스팅해야한다.
#     h_input = (int*)malloc(byte_size);
#
#     time_t t;
#     srand((unsigned)time(&t));
#     for(int i=0; i<size; i++) {
#         h_input[i] = rand() & 0xff;
#     }
#
#     int * d_input;
#     // 첫번째 인자로 더블 포인터 혹은 포인터에 포인터가 들어간다.
#     cudaMalloc((void**)&d_input, byte_size);
#
#     cudaMemcpy(d_input, h_input, byte_size, cudaMemcpyHostToDevice);
#
#     dim3 block(64);
#     dim3 grid(2);
#
#     mem_trs_test<<<grid, block>>>(d_input);
#     cudaDeviceSynchronize();
#
#     cudaFree(d_input);
#     free(h_input);
#
#     cudaDeviceReset();
#     return 0;
# }
# Out:
# tid : 0, gid : 64, value : 253
# tid : 1, gid : 65, value : 232
# tid : 2, gid : 66, value : 210
# tid : 3, gid : 67, value : 181
# tid : 4, gid : 68, value : 62
# tid : 5, gid : 69, value : 19
# tid : 6, gid : 70, value : 37
# tid : 7, gid : 71, value : 24
# tid : 8, gid : 72, value : 233
# tid : 9, gid : 73, value : 216
# tid : 10, gid : 74, value : 17
# tid : 11, gid : 75, value : 25
# tid : 12, gid : 76, value : 183
# tid : 13, gid : 77, value : 250
# tid : 14, gid : 78, value : 48
# tid : 15, gid : 79, value : 67
# tid : 16, gid : 80, value : 65
# tid : 17, gid : 81, value : 58
# tid : 18, gid : 82, value : 167
# tid : 19, gid : 83, value : 116
# tid : 20, gid : 84, value : 184
# tid : 21, gid : 85, value : 221
# tid : 22, gid : 86, value : 222
# tid : 23, gid : 87, value : 160
# tid : 24, gid : 88, value : 46
# tid : 25, gid : 89, value : 65
# tid : 26, gid : 90, value : 200
# tid : 27, gid : 91, value : 167
# tid : 28, gid : 92, value : 191
# tid : 29, gid : 93, value : 172
# tid : 30, gid : 94, value : 91
# tid : 31, gid : 95, value : 188
# tid : 32, gid : 96, value : 148
# tid : 33, gid : 97, value : 46
# tid : 34, gid : 98, value : 113
# tid : 35, gid : 99, value : 210
# tid : 36, gid : 100, value : 65
# tid : 37, gid : 101, value : 150
# tid : 38, gid : 102, value : 235
# tid : 39, gid : 103, value : 42
# tid : 40, gid : 104, value : 110
# tid : 41, gid : 105, value : 252
# tid : 42, gid : 106, value : 67
# tid : 43, gid : 107, value : 38
# tid : 44, gid : 108, value : 246
# tid : 45, gid : 109, value : 115
# tid : 46, gid : 110, value : 105
# tid : 47, gid : 111, value : 55
# tid : 48, gid : 112, value : 173
# tid : 49, gid : 113, value : 17
# tid : 50, gid : 114, value : 172
# tid : 51, gid : 115, value : 102
# tid : 52, gid : 116, value : 238
# tid : 53, gid : 117, value : 138
# tid : 54, gid : 118, value : 6
# tid : 55, gid : 119, value : 28
# tid : 56, gid : 120, value : 203
# tid : 57, gid : 121, value : 207
# tid : 58, gid : 122, value : 195
# tid : 59, gid : 123, value : 138
# tid : 60, gid : 124, value : 123
# tid : 61, gid : 125, value : 31
# tid : 62, gid : 126, value : 70
# tid : 63, gid : 127, value : 16
# tid : 0, gid : 0, value : 124
# tid : 1, gid : 1, value : 18
# tid : 2, gid : 2, value : 99
# tid : 3, gid : 3, value : 72
# tid : 4, gid : 4, value : 228
# tid : 5, gid : 5, value : 57
# tid : 6, gid : 6, value : 82
# tid : 7, gid : 7, value : 34
# tid : 8, gid : 8, value : 184
# tid : 9, gid : 9, value : 132
# tid : 10, gid : 10, value : 149
# tid : 11, gid : 11, value : 67
# tid : 12, gid : 12, value : 30
# tid : 13, gid : 13, value : 90
# tid : 14, gid : 14, value : 43
# tid : 15, gid : 15, value : 239
# tid : 16, gid : 16, value : 230
# tid : 17, gid : 17, value : 173
# tid : 18, gid : 18, value : 94
# tid : 19, gid : 19, value : 243
# tid : 20, gid : 20, value : 216
# tid : 21, gid : 21, value : 236
# tid : 22, gid : 22, value : 116
# tid : 23, gid : 23, value : 209
# tid : 24, gid : 24, value : 54
# tid : 25, gid : 25, value : 105
# tid : 26, gid : 26, value : 27
# tid : 27, gid : 27, value : 248
# tid : 28, gid : 28, value : 64
# tid : 29, gid : 29, value : 40
# tid : 30, gid : 30, value : 27
# tid : 31, gid : 31, value : 188
# tid : 32, gid : 32, value : 58
# tid : 33, gid : 33, value : 127
# tid : 34, gid : 34, value : 4
# tid : 35, gid : 35, value : 30
# tid : 36, gid : 36, value : 184
# tid : 37, gid : 37, value : 86
# tid : 38, gid : 38, value : 64
# tid : 39, gid : 39, value : 112
# tid : 40, gid : 40, value : 218
# tid : 41, gid : 41, value : 214
# tid : 42, gid : 42, value : 179
# tid : 43, gid : 43, value : 249
# tid : 44, gid : 44, value : 48
# tid : 45, gid : 45, value : 223
# tid : 46, gid : 46, value : 232
# tid : 47, gid : 47, value : 22
# tid : 48, gid : 48, value : 140
# tid : 49, gid : 49, value : 71
# tid : 50, gid : 50, value : 10
# tid : 51, gid : 51, value : 100
# tid : 52, gid : 52, value : 51
# tid : 53, gid : 53, value : 126
# tid : 54, gid : 54, value : 53
# tid : 55, gid : 55, value : 106
# tid : 56, gid : 56, value : 232
# tid : 57, gid : 57, value : 81
# tid : 58, gid : 58, value : 98
# tid : 59, gid : 59, value : 40
# tid : 60, gid : 60, value : 121
# tid : 61, gid : 61, value : 126
# tid : 62, gid : 62, value : 228
# tid : 63, gid : 63, value : 180

# %% [markdown]
# ### **입력 데이터가 커널이 정한 데이터보다 클 때 (넘칠 때)**
# - 배열 크기를 배열과 같이 넘겨줌으로써 if(gid < size)를 통해 해결

# %%
# %%cu
# #include "cuda_runtime.h"
# #include "device_launch_parameters.h"
# #include <stdio.h>
# #include <stdlib.h>
# #include <cstring>
# #include <time.h>
#
# __global__ void mem_trs_test2(int * input, int size) {
#     int gid = blockIdx.x * blockDim.x + threadIdx.x;
#
#     if(gid < size)
#         printf("tid : %d, gid : %d, value : %d \n", threadIdx.x, gid, input[gid]);
# }
#
# int main() {
#
#     int size = 150;
#     int byte_size = size * sizeof(int);
#
#     int * h_input;
#     // 말록 함수는 void 포인터를 반환하므로 원하는 타입의 포인터로 캐스팅해야한다.
#     h_input = (int*)malloc(byte_size);
#
#     time_t t;
#     srand((unsigned)time(&t));
#     for(int i=0; i<size; i++) {
#         h_input[i] = rand() & 0xff;
#     }
#
#     int * d_input;
#     // 첫번째 인자로 더블 포인터 혹은 포인터에 포인터가 들어간다.
#     cudaMalloc((void**)&d_input, byte_size);
#
#     cudaMemcpy(d_input, h_input, byte_size, cudaMemcpyHostToDevice);
#
#     // 총 160개의 스레드
#     dim3 block(32);
#     dim3 grid(5);
#
#     mem_trs_test<<<grid, block>>>(d_input, size);
#     cudaDeviceSynchronize();
#
#     cudaFree(d_input);
#     free(h_input);
#
#     cudaDeviceReset();
#     return 0;
# }
# Out:
# /tmp/tmp8g7a0hx6/f8ed1d04-61fb-47d5-b546-47a1be17150a.cu(41): error: identifier "mem_trs_test" is undefined
#
# 1 error detected in the compilation of "/tmp/tmp8g7a0hx6/f8ed1d04-61fb-47d5-b546-47a1be17150a.cu".
